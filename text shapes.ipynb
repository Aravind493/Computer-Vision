# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

# %%
img1 = np.zeros(shape=[500,500,3], dtype=np.int32)

# %%
plt.imshow(img1)

# %%
font = cv2.FONT_HERSHEY_PLAIN
cv2.putText(img1,text="Tammineedi Aravind", org=(10,450),fontFace=font,fontScale=3,color=(255,255,255),thickness=2)
plt.imshow(img1)
