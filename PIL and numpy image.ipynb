# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image ##pil is python image library

# %%
img = Image.open("C:/Users/tatav/Documents/Resume/cv1.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1599>

# %%
img.mode
# Out:
# 'RGB'

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (1599, 1200, 3)

# %% [markdown]
# row pixels, column pixels , RGB colors
# (1599,1200,30)

# %%
plt.imshow(img_array)

# %%
img1= img_array.copy()

# %%
img2= img_array.copy()

# %%
img3= img_array.copy()

# %%
img1[:,:,0]
# Out:
# array([[171, 172, 175, ..., 170, 170, 170],
#        [171, 172, 175, ..., 171, 171, 171],
#        [171, 172, 175, ..., 171, 171, 171],
#        ...,
#        [190, 190, 191, ..., 179, 177, 180],
#        [188, 189, 190, ..., 180, 178, 180],
#        [189, 189, 190, ..., 180, 178, 181]], dtype=uint8)

# %%
img1[:,:,0]=0
plt.imshow(img1)

# %%
img2[:,:,1]
# Out:
# array([[173, 174, 176, ..., 168, 168, 168],
#        [173, 174, 176, ..., 169, 169, 169],
#        [173, 174, 176, ..., 169, 169, 169],
#        ...,
#        [185, 185, 186, ..., 176, 174, 177],
#        [183, 184, 185, ..., 177, 175, 177],
#        [184, 184, 185, ..., 177, 175, 178]], dtype=uint8)

# %%
img2[:,:,1] = 0
plt.imshow(img2)

# %%
img3[:,:,2]
# Out:
# array([[159, 160, 162, ..., 155, 155, 155],
#        [159, 160, 162, ..., 156, 156, 156],
#        [159, 160, 162, ..., 156, 156, 156],
#        ...,
#        [165, 165, 166, ..., 159, 159, 162],
#        [163, 164, 165, ..., 160, 160, 162],
#        [164, 164, 165, ..., 160, 160, 163]], dtype=uint8)

# %%
img3[:,:,2]=0
plt.imshow(img3)
