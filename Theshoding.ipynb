# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("C:/Users/tatav/Documents/Resume/cv1.jpg")

# %%
plt.imshow(img)

# %%
img=cv2.imread("C:/Users/tatav/Documents/Resume/cv1.jpg",0)

# %%
plt.imshow(img)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lim,img1=cv2.threshold(img,100,255,cv2.THRESH_BINARY)
plt.imshow(img1,cmap="gray")

# %%
lim,img1=cv2.threshold(img,100,255,cv2.THRESH_BINARY_INV)
plt.imshow(img1,cmap="gray")

# %%
lim,img1=cv2.threshold(img,100,255,cv2.THRESH_TRUNC)
plt.imshow(img1,cmap="gray")

# %%
lim,img1=cv2.threshold(img,100,255,cv2.THRESH_TOZERO)
plt.imshow(img1,cmap="gray")

# %%
lim,img1=cv2.threshold(img,100,255,cv2.THRESH_TOZERO_INV)
plt.imshow(img1,cmap="gray")
