# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("C:/Users/tatav/Documents/Resume/cv1.jpg")

# %%
plt.imshow(img)

# %%
pic=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %%
pic1=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(pic1)

# %%
pic3=cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
plt.imshow(pic3)
