# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("C:/Users/tatav/Documents/Resume/cv1.jpg")

# %%
img.shape
# Out:
# (1599, 1200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %% [markdown]
# this happend due to cv2 reads img in bgr format not in rgb

# %% [markdown]
# BGR 2 RGB

# %%
pic=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %%
pic_resize = cv2.resize(pic,(500,1000))
plt.imshow(pic_resize)

# %%
new_pic = cv2.resize(pic,(0,0),pic,0.5,0.5)
plt.imshow(new_pic)
